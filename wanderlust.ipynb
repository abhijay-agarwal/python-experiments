# %%
from selenium import webdriver as wd
from bs4 import BeautifulSoup as bs

# %%
browser = wd.Chrome()
browser.implicitly_wait(10)
browser.get('https://www.wanderlust.co.uk/content/your-115-greatest-travel-experiences/')

# %%
html = browser.page_source
soup = bs(html, 'html.parser')
h3_elements = soup.find_all('h3')
for h3 in h3_elements:
  print(h3.text)
# Out:
# 1. Cruise the Galápagos Islands, Ecuador
# 2. Meet turtles and sloths, Costa Rica
# 3. Meet mountain gorillas, Rwanda/Uganda
# 4. Discover wildlife in Madagascar
# 5. Snorkel in Bora Bora, French Polynesia
# 6. Iguazu Falls, Argentina/Brazil
# 7. Appreciate all that ice, Antarctica
# 8. Sit on the summit of Stromboli, Italy
# 9. Salar de Uyuni salt flats, Bolivia
# 10. Attend Naadam Festival, Mongolia
# 11. Visit the temples of Bagan, Myanmar
# 12. Watch the sun rise over Angkor Wat, Cambodia
# 13. Get a glimpse of ancient Petra, Jordan
# 14. Take a mokoro through the Okavango Delta, Botswana
# 15. Travel the Karakoram Highway, Pakistan
# 16. Trek to Machu Picchu, Peru
# 17. Watch the Perito Moreno Glacier, Argentina
# 18. Hike the Tongariro Crossing, New Zealand
# 19. Meet moai in Easter Island, Chile
# 20. Lounge on islands, Malaysia
# 21. Marvel at the Mayan ruins of Tikal, Guatemala
# 22. Delve into the dunes of Sossusvlei, Namibia
# 23. Ride the Trans-Siberian Railway, Russia
# 24. Roam the remains at Hampi, India
# 25. Sit among 100,000 king penguins, South Georgia
# 26. See wild orang utans, Borneo
# 27. Go on a bush safari, Botswana
# 28. Get close to Mount Everest, Nepal
# 29. Feel the spray, Victoria Falls, Zambia/Zimbabwe
# 30. Glimpse Torres del Paine, Chile
# 31. Plunge into the wilderness, Alaska, USA
# 32. Catch your first sight of the Taj Mahal, Agra, India
# 33. Explore Cappadocia, Turkey
# 34. Visit the Jokhang and Potala Palace, Tibet
# 35. Jaguar-spot in the Pantanal, Brazil
# 36. Look out for bears, Canada
# 37. Waterhole-watch in Etosha National Park, Namibia
# 38. Fly over the Skeleton Coast, Namibia
# 39. Glimpse the peaks of the Himalaya
# 40. Climb to Tiger’s Nest, Bhutan
# 41. See the Great Migration, Kenya/Tanzania
# 42. Walk the Great Wall of China
# 43. Paddle to Angel Falls, Venezuela
# 44. Motorbiking or biking, Vietnam
# 45. Hover over Franz Josef Glacier, New Zealand
# 46. Raft the Zambezi, Zambia
# 47. Rock out in Utah’s canyons, USA
# 48. Walking safari in South Luangwa National Park, Zambia
# 49. Explore Banff National Park, Canada
# 50. Gawp at the Grand Canyon, USA
# 51. Climb Kilimanjaro, Tanzania
# 52. Get up-close with elephants, South Africa
# 53. Be bewitched by the northern lights
# 54. See a solar eclipse
# 55. Temple-gaze at Abu Simbel, Egypt
# 56. Husky mush in Lapland, Sweden
# 57. Sea-kayak with orca, Canada
# 58. Salsa in Havana, Cuba
# 59. Kayak in Fiordland, South Island, New Zealand
# 60. Stroll old Cartagena, Colombia
# 61. Yomp around Yosemite National Park, California, USA
# 62. Fancy-free back-packing, Australia
# 63. Browse Hoi An, Vietnam
# 64. Have fun on Fraser Island, Queensland, Australia
# 65. Feel like a movie star in New York, USA
# 66. Stand atop the rock city of Sigiriya, Sri Lanka
# 67. Boat up the Mekong, Laos
# 68. Sail out on Milford Sound, New Zealand
# 69. Atacama Desert and El Tatio geysers, Chile
# 70. Dive the cenotes, Yucatán, Mexico
# 71. Roam Rome and the Vatican, Italy
# 72. Watch whales in the Gulf of St Lawrence, Canada
# 73. Admire Yellowstone National Park, Wyoming, USA
# 74. Watch whales and dolphins, New Zealand
# 75. Go wild in Kakadu National Park, Australia
# 76. Climb Table Mountain, Cape Town, South Africa
# 77. Get your motor running on a road trip, USA
# 78. Watch sunrise and sunset at Uluru, Australia
# 79. Kerala's backwaters, India
# 80. Spice things up on Zanzibar, Tanzania
# 81. Swim in marine-life heaven, Caye Caulker, Belize
# 82. Get spiritual on the Ganges, India
# 83. Climb Sydney Harbour Bridge, Australia
# 84. Hike Taman Negara National Park, Malaysia
# 85. Live local on Lake Titicaca, Peru
# 86. Go wild on the Falkland Islands
# 87. Sleep out in Wadi Rum, Jordan
# 88. Spot rhinos in Royal Chitwan National Park, Nepal
# 89. Hang out in Halong Bay, Vietnam
# 90. Visit Auschwitz, Poland
# 91. InterRail around Europe
# 92. Uncover Kyoto, Japan
# 93. Get lost in Venice, Italy
# 94. Spot polar bears in Spitsbergen, Norway
# 95. Explore the backstreets of Kathmandu, Nepal
# 96. Whitewater rafting, Nepal
# 97. Roam the Outer Hebrides, Scotland
# 98. Dive the Great Barrier Reef, Australia
# 99. Soak up Santorini, Greece
# 100. Descend into Thrihnukagigur volcano, Iceland
# 101. Seek out tigers, India
# 102. Walk Camino de Santiago, Spain
# 103. Trek the steppe, Kyrgyzstan
# 104. Explore Mayan ruins, Belize
# 105. Traverse the Silk Road, China to Turkey
# 106. See the elusive Southern Lights
# 107. Travel through the three Guianas
# 108. Get lost in markets, Morocco
# 109. Meet the world’s oldest animal, St Helena, British Overseas Territory
# 110. Trek the Transcarioca Trail, Brazil
# 111. Island-hop, Indonesia
# 112. Explore the golden circle, Iceland
# 113. Birdwatch, Papua New Guinea
# More inspiration? Keep reading:
# Wanderlust's 2020 Hot List: 15 best places to see (when you can!)
# 25 life-enriching travel experiences
# 23 Big Bucket List adventures
# How to travel the world and get paid for it
# Quiz: How many classic bucket list experiences can you tick off?
# Wanderlust Reader Travel Awards 2020: The results
# Wanderlust Hot List: The top 15 places you need to visit in 2020
# 25 big bucket list adventures
# Your top tours: The most popular Trip Finder adventures of 2019
# Hot, hot, hot: 15 sizzling tours to 2020’s Hot List destinations
# Trip Finder Find your perfect trip

# %%
# keep only the first 113 elements in h3_elements and make sure only the text is kept
experience_elements = h3_elements[:113]
experience_texts = [h3.text for h3 in experience_elements]
for a in experience_texts:
  print(a)
# Out:
# 1. Cruise the Galápagos Islands, Ecuador
# 2. Meet turtles and sloths, Costa Rica
# 3. Meet mountain gorillas, Rwanda/Uganda
# 4. Discover wildlife in Madagascar
# 5. Snorkel in Bora Bora, French Polynesia
# 6. Iguazu Falls, Argentina/Brazil
# 7. Appreciate all that ice, Antarctica
# 8. Sit on the summit of Stromboli, Italy
# 9. Salar de Uyuni salt flats, Bolivia
# 10. Attend Naadam Festival, Mongolia
# 11. Visit the temples of Bagan, Myanmar
# 12. Watch the sun rise over Angkor Wat, Cambodia
# 13. Get a glimpse of ancient Petra, Jordan
# 14. Take a mokoro through the Okavango Delta, Botswana
# 15. Travel the Karakoram Highway, Pakistan
# 16. Trek to Machu Picchu, Peru
# 17. Watch the Perito Moreno Glacier, Argentina
# 18. Hike the Tongariro Crossing, New Zealand
# 19. Meet moai in Easter Island, Chile
# 20. Lounge on islands, Malaysia
# 21. Marvel at the Mayan ruins of Tikal, Guatemala
# 22. Delve into the dunes of Sossusvlei, Namibia
# 23. Ride the Trans-Siberian Railway, Russia
# 24. Roam the remains at Hampi, India
# 25. Sit among 100,000 king penguins, South Georgia
# 26. See wild orang utans, Borneo
# 27. Go on a bush safari, Botswana
# 28. Get close to Mount Everest, Nepal
# 29. Feel the spray, Victoria Falls, Zambia/Zimbabwe
# 30. Glimpse Torres del Paine, Chile
# 31. Plunge into the wilderness, Alaska, USA
# 32. Catch your first sight of the Taj Mahal, Agra, India
# 33. Explore Cappadocia, Turkey
# 34. Visit the Jokhang and Potala Palace, Tibet
# 35. Jaguar-spot in the Pantanal, Brazil
# 36. Look out for bears, Canada
# 37. Waterhole-watch in Etosha National Park, Namibia
# 38. Fly over the Skeleton Coast, Namibia
# 39. Glimpse the peaks of the Himalaya
# 40. Climb to Tiger’s Nest, Bhutan
# 41. See the Great Migration, Kenya/Tanzania
# 42. Walk the Great Wall of China
# 43. Paddle to Angel Falls, Venezuela
# 44. Motorbiking or biking, Vietnam
# 45. Hover over Franz Josef Glacier, New Zealand
# 46. Raft the Zambezi, Zambia
# 47. Rock out in Utah’s canyons, USA
# 48. Walking safari in South Luangwa National Park, Zambia
# 49. Explore Banff National Park, Canada
# 50. Gawp at the Grand Canyon, USA
# 51. Climb Kilimanjaro, Tanzania
# 52. Get up-close with elephants, South Africa
# 53. Be bewitched by the northern lights
# 54. See a solar eclipse
# 55. Temple-gaze at Abu Simbel, Egypt
# 56. Husky mush in Lapland, Sweden
# 57. Sea-kayak with orca, Canada
# 58. Salsa in Havana, Cuba
# 59. Kayak in Fiordland, South Island, New Zealand
# 60. Stroll old Cartagena, Colombia
# 61. Yomp around Yosemite National Park, California, USA
# 62. Fancy-free back-packing, Australia
# 63. Browse Hoi An, Vietnam
# 64. Have fun on Fraser Island, Queensland, Australia
# 65. Feel like a movie star in New York, USA
# 66. Stand atop the rock city of Sigiriya, Sri Lanka
# 67. Boat up the Mekong, Laos
# 68. Sail out on Milford Sound, New Zealand
# 69. Atacama Desert and El Tatio geysers, Chile
# 70. Dive the cenotes, Yucatán, Mexico
# 71. Roam Rome and the Vatican, Italy
# 72. Watch whales in the Gulf of St Lawrence, Canada
# 73. Admire Yellowstone National Park, Wyoming, USA
# 74. Watch whales and dolphins, New Zealand
# 75. Go wild in Kakadu National Park, Australia
# 76. Climb Table Mountain, Cape Town, South Africa
# 77. Get your motor running on a road trip, USA
# 78. Watch sunrise and sunset at Uluru, Australia
# 79. Kerala's backwaters, India
# 80. Spice things up on Zanzibar, Tanzania
# 81. Swim in marine-life heaven, Caye Caulker, Belize
# 82. Get spiritual on the Ganges, India
# 83. Climb Sydney Harbour Bridge, Australia
# 84. Hike Taman Negara National Park, Malaysia
# 85. Live local on Lake Titicaca, Peru
# 86. Go wild on the Falkland Islands
# 87. Sleep out in Wadi Rum, Jordan
# 88. Spot rhinos in Royal Chitwan National Park, Nepal
# 89. Hang out in Halong Bay, Vietnam
# 90. Visit Auschwitz, Poland
# 91. InterRail around Europe
# 92. Uncover Kyoto, Japan
# 93. Get lost in Venice, Italy
# 94. Spot polar bears in Spitsbergen, Norway
# 95. Explore the backstreets of Kathmandu, Nepal
# 96. Whitewater rafting, Nepal
# 97. Roam the Outer Hebrides, Scotland
# 98. Dive the Great Barrier Reef, Australia
# 99. Soak up Santorini, Greece
# 100. Descend into Thrihnukagigur volcano, Iceland
# 101. Seek out tigers, India
# 102. Walk Camino de Santiago, Spain
# 103. Trek the steppe, Kyrgyzstan
# 104. Explore Mayan ruins, Belize
# 105. Traverse the Silk Road, China to Turkey
# 106. See the elusive Southern Lights
# 107. Travel through the three Guianas
# 108. Get lost in markets, Morocco
# 109. Meet the world’s oldest animal, St Helena, British Overseas Territory
# 110. Trek the Transcarioca Trail, Brazil
# 111. Island-hop, Indonesia
# 112. Explore the golden circle, Iceland
# 113. Birdwatch, Papua New Guinea

# %%
import openai
openai.organization = "org-j4pk5JHCEmB8W8ciBhRrs8Ph"
openai.api_key = "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"

first_58 = openai.ChatCompletion.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": 
     '''
      1. Cruise the Galápagos Islands, Ecuador
      2. Meet turtles and sloths, Costa Rica
      3. Meet mountain gorillas, Rwanda/Uganda
      4. Discover wildlife in Madagascar
      5. Snorkel in Bora Bora, French Polynesia
      6. Iguazu Falls, Argentina/Brazil
      7. Appreciate all that ice, Antarctica
      8. Sit on the summit of Stromboli, Italy
      9. Salar de Uyuni salt flats, Bolivia
      10. Attend Naadam Festival, Mongolia
      11. Visit the temples of Bagan, Myanmar
      12. Watch the sun rise over Angkor Wat, Cambodia
      13. Get a glimpse of ancient Petra, Jordan
      14. Take a mokoro through the Okavango Delta, Botswana
      15. Travel the Karakoram Highway, Pakistan
      16. Trek to Machu Picchu, Peru
      17. Watch the Perito Moreno Glacier, Argentina
      18. Hike the Tongariro Crossing, New Zealand
      19. Meet moai in Easter Island, Chile
      20. Lounge on islands, Malaysia
      21. Marvel at the Mayan ruins of Tikal, Guatemala
      22. Delve into the dunes of Sossusvlei, Namibia
      23. Ride the Trans-Siberian Railway, Russia
      24. Roam the remains at Hampi, India
      25. Sit among 100,000 king penguins, South Georgia
      26. See wild orang utans, Borneo
      27. Go on a bush safari, Botswana
      28. Get close to Mount Everest, Nepal
      29. Feel the spray, Victoria Falls, Zambia/Zimbabwe
      30. Glimpse Torres del Paine, Chile
      31. Plunge into the wilderness, Alaska, USA
      32. Catch your first sight of the Taj Mahal, Agra, India
      33. Explore Cappadocia, Turkey
      34. Visit the Jokhang and Potala Palace, Tibet
      35. Jaguar-spot in the Pantanal, Brazil
      36. Look out for bears, Canada
      37. Waterhole-watch in Etosha National Park, Namibia
      38. Fly over the Skeleton Coast, Namibia
      39. Glimpse the peaks of the Himalaya
      40. Climb to Tiger's Nest, Bhutan
      41. See the Great Migration, Kenya/Tanzania
      42. Walk the Great Wall of China
      43. Paddle to Angel Falls, Venezuela
      44. Motorbiking or biking, Vietnam
      45. Hover over Franz Josef Glacier, New Zealand
      46. Raft the Zambezi, Zambia
      47. Rock out in Utah's canyons, USA
      48. Walking safari in South Luangwa National Park, Zambia
      49. Explore Banff National Park, Canada
      50. Gawp at the Grand Canyon, USA
      51. Climb Kilimanjaro, Tanzania
      52. Get up-close with elephants, South Africa
      53. Be bewitched by the northern lights
      54. See a solar eclipse
      55. Temple-gaze at Abu Simbel, Egypt
      56. Husky mush in Lapland, Sweden
      57. Sea-kayak with orca, Canada
      58. Salsa in Havana, Cuba


      can you return a non numbered string of longitudes and latitudes for each of these places, except the solar eclipse one, with no labels or anything, encapsulating each pair in parentheses and separating the pairs with line breaks, for ambiguous/multi-location items just give me the midpoint of all the locations, ensure all 58 items in this list have a corresponding latitude and longitude, except for ones like the solar eclipse one, example format:

      (-41.4141, 18.1351)\n(0.0144, 29.41414)\nrest of list 
      '''
     }
  ]
)

print(first_58.choices[0].message)

coords = first_58.choices[0].message.content.split('\n')
for c in coords:
  print(c)

print(len(coords))
# Out:
# {
#   "content": "(-0.9721, -90.9656)\n(9.9281, -84.0907)\n(-1.9435, 29.8776)\n(-18.7669, 46.8691)\n(-16.5004, -151.7415)\n(-25.6953, -54.4367)\n(-64.7745, -62.7277)\n(38.7897, 15.2130)\n(-20.1336, -67.4891)\n(47.0253, 104.2370)\n(21.1717, 94.8610)\n(12.8166, 104.8943)\n(30.3285, 35.4427)\n(-19.1176, 23.1759)\n(35.6783, 74.4797)\n(15.8403, -69.1629)\n(-39.1659, 175.5039)\n(-27.1212, -109.3664)\n(17.2798, -89.6213)\n(-24.7501, 15.2689)\n(55.3422, 86.0872)\n(15.3350, 76.4601)\n(-54.2766, -36.5081)\n(2.9851, 113.3959)\n(-19.1961, 22.4560)\n(27.9881, 86.9250)\n(-17.9269, 25.8285)\n(71.0072, -140.7589)\n(27.1750, 78.0422)\n(38.6431, 34.8287)\n(29.6594, 91.1166)\n(-18.0610, -56.3573)\n(51.5638, -116.4254)\n(36.1069, -112.1126)\n(-3.0759, 37.3532)\n(40.4319, 116.5704)\n(5.9672, -62.5342)\n(14.0583, 108.2772)\n(-43.4627, 170.1824)\n(-17.9248, 25.8585)\n(51.1788, -115.5716)\n(36.1069, -112.1126)\n(-3.0674, 37.3556)\n(-3.1601, 37.4714)\n(26.8206, 30.8025)\n(68.3119, 22.7289)\n(53.7129, -130.4472)\n(-18.7899, 16.9906)\n(38.5858, -109.6159)\n(-13.1748, 27.8283)\n(51.1450, -1.8414)\n(3.1390, 101.6869)\n(16.7357, -92.6376)",
#   "role": "assistant"
# }
# (-0.9721, -90.9656)
# (9.9281, -84.0907)
# (-1.9435, 29.8776)
# (-18.7669, 46.8691)
# (-16.5004, -151.7415)
# (-25.6953, -54.4367)
# (-64.7745, -62.7277)
# (38.7897, 15.2130)
# (-20.1336, -67.4891)
# (47.0253, 104.2370)
# (21.1717, 94.8610)
# (12.8166, 104.8943)
# (30.3285, 35.4427)
# (-19.1176, 23.1759)
# (35.6783, 74.4797)
# (15.8403, -69.1629)
# (-39.1659, 175.5039)
# (-27.1212, -109.3664)
# (17.2798, -89.6213)
# (-24.7501, 15.2689)
# (55.3422, 86.0872)
# (15.3350, 76.4601)
# (-54.2766, -36.5081)
# (2.9851, 113.3959)
# (-19.1961, 22.4560)
# (27.9881, 86.9250)
# (-17.9269, 25.8285)
# (71.0072, -140.7589)
# (27.1750, 78.0422)
# (38.6431, 34.8287)
# (29.6594, 91.1166)
# (-18.0610, -56.3573)
# (51.5638, -116.4254)
# (36.1069, -112.1126)
# (-3.0759, 37.3532)
# (40.4319, 116.5704)
# (5.9672, -62.5342)
# (14.0583, 108.2772)
# (-43.4627, 170.1824)
# (-17.9248, 25.8585)
# (51.1788, -115.5716)
# (36.1069, -112.1126)
# (-3.0674, 37.3556)
# (-3.1601, 37.4714)
# (26.8206, 30.8025)
# (68.3119, 22.7289)
# (53.7129, -130.4472)
# (-18.7899, 16.9906)
# (38.5858, -109.6159)
# (-13.1748, 27.8283)
# (51.1450, -1.8414)
# (3.1390, 101.6869)
# (16.7357, -92.6376)
# 53

# %%
rest = openai.ChatCompletion.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": '''
59. Kayak in Fiordland, South Island, New Zealand 
60. Stroll old Cartagena, Colombia
61. Yomp around Yosemite National Park, California, USA
62. Fancy-free back-packing, Australia
63. Browse Hoi An, Vietnam
64. Have fun on Fraser Island, Queensland, Australia
65. Feel like a movie star in New York, USA
66. Stand atop the rock city of Sigiriya, Sri Lanka
67. Boat up the Mekong, Laos
68. Sail out on Milford Sound, New Zealand
69. Atacama Desert and El Tatio geysers, Chile
70. Dive the cenotes, Yucatán, Mexico
71. Roam Rome and the Vatican, Italy
72. Watch whales in the Gulf of St Lawrence, Canada
73. Admire Yellowstone National Park, Wyoming, USA
74. Watch whales and dolphins, New Zealand
75. Go wild in Kakadu National Park, Australia
76. Climb Table Mountain, Cape Town, South Africa
77. Get your motor running on a road trip, USA
78. Watch sunrise and sunset at Uluru, Australia
79. Kerala's backwaters, India
80. Spice things up on Zanzibar, Tanzania
81. Swim in marine-life heaven, Caye Caulker, Belize
82. Get spiritual on the Ganges, India
83. Climb Sydney Harbour Bridge, Australia
84. Hike Taman Negara National Park, Malaysia
85. Live local on Lake Titicaca, Peru
86. Go wild on the Falkland Islands
87. Sleep out in Wadi Rum, Jordan
88. Spot rhinos in Royal Chitwan National Park, Nepal
89. Hang out in Halong Bay, Vietnam
90. Visit Auschwitz, Poland
91. InterRail around Europe
92. Uncover Kyoto, Japan
93. Get lost in Venice, Italy
94. Spot polar bears in Spitsbergen, Norway
95. Explore the backstreets of Kathmandu, Nepal
96. Whitewater rafting, Nepal
97. Roam the Outer Hebrides, Scotland
98. Dive the Great Barrier Reef, Australia
99. Soak up Santorini, Greece
100. Descend into Thrihnukagigur volcano, Iceland
101. Seek out tigers, India
102. Walk Camino de Santiago, Spain
103. Trek the steppe, Kyrgyzstan
104. Explore Mayan ruins, Belize
105. Traverse the Silk Road, China to Turkey
106. See the elusive Southern Lights
107. Travel through the three Guianas
108. Get lost in markets, Morocco
109. Meet the world's oldest animal, St Helena, British Overseas Territory
110. Trek the Transcarioca Trail, Brazil
111. Island-hop, Indonesia
112. Explore the golden circle, Iceland
113. Birdwatch, Papua New Guinea

can you return a non numbered string of longitudes and latitudes for each of these places, except the solar eclipse one, with no labels or anything, encapsulating each pair in parentheses and separating the pairs with line breaks, for ambiguous/multi-location items just give me the midpoint of all the locations, ensure all items in this list have exactly one corresponding latitude and longitude, example format:

      (-41.4141, 18.1351)\n(0.0144, 29.41414)\nrest of list '''}
  ]
)

print(rest.choices[0].message)

coords2 = rest.choices[0].message.content.split('\n')
for c in coords2:
  print(c)

print(len(coords2))
# Out:
# {
#   "content": "(-44.6715, 167.9259)\n(10.4231, -75.5492)\n(37.8651, -119.5383)\n(-24.7761, 134.755)\n(15.8799, 108.323)\n(-25.2665, 153.1433)\n(40.7128, -74.0060)\n(7.9500, 80.7500)\n(19.8837, 102.1340)\n(-44.6715, 167.9259)\n(-22.9083, -68.1997)\n(20.2114, -87.4624)\n(41.9028, 12.4964)\n(50.1364, -64.2245)\n(44.4279, -110.5885)\n(-41.3926, 174.6142)\n(-23.6260, -67.6860)\n(20.4660, 86.4339)\n(17.5028, -88.2024)\n(25.3051, 82.9873)\n(-33.8523, 151.2108)\n(4.5833, 102.4167)\n(-16.5167, -68.1500)\n(-51.7963, -59.5236)\n(29.7589, 35.0544)\n(27.6562, 84.4300)\n(-33.9422, 151.2257)\n(4.3907, 101.9059)\n(-15.8445, -69.3058)\n(-51.7963, -59.5236)\n(29.3697, 47.6603)\n(27.5321, 84.4173)\n(28.5796, -16.2297)\n(-22.8736, -43.2887)\n(64.0575, -21.9247)\n(22.3964, 114.1095)\n(45.4408, 12.3155)\n(78.1551, 15.3188)\n(27.6581, -8.1110)\n(-15.9633, -5.7089)\n(-22.9068, -43.1729)\n(64.1466, -21.9426)\n(22.8939, 92.7182)\n(42.6316, -71.3162)\n(-2.1600, -79.9060)\n(-15.8267, -47.9218)\n(-8.4553, 119.8691)\n(64.1265, -21.8174)\n(-6.3144, 143.9555)",
#   "role": "assistant"
# }
# (-44.6715, 167.9259)
# (10.4231, -75.5492)
# (37.8651, -119.5383)
# (-24.7761, 134.755)
# (15.8799, 108.323)
# (-25.2665, 153.1433)
# (40.7128, -74.0060)
# (7.9500, 80.7500)
# (19.8837, 102.1340)
# (-44.6715, 167.9259)
# (-22.9083, -68.1997)
# (20.2114, -87.4624)
# (41.9028, 12.4964)
# (50.1364, -64.2245)
# (44.4279, -110.5885)
# (-41.3926, 174.6142)
# (-23.6260, -67.6860)
# (20.4660, 86.4339)
# (17.5028, -88.2024)
# (25.3051, 82.9873)
# (-33.8523, 151.2108)
# (4.5833, 102.4167)
# (-16.5167, -68.1500)
# (-51.7963, -59.5236)
# (29.7589, 35.0544)
# (27.6562, 84.4300)
# (-33.9422, 151.2257)
# (4.3907, 101.9059)
# (-15.8445, -69.3058)
# (-51.7963, -59.5236)
# (29.3697, 47.6603)
# (27.5321, 84.4173)
# (28.5796, -16.2297)
# (-22.8736, -43.2887)
# (64.0575, -21.9247)
# (22.3964, 114.1095)
# (45.4408, 12.3155)
# (78.1551, 15.3188)
# (27.6581, -8.1110)
# (-15.9633, -5.7089)
# (-22.9068, -43.1729)
# (64.1466, -21.9426)
# (22.8939, 92.7182)
# (42.6316, -71.3162)
# (-2.1600, -79.9060)
# (-15.8267, -47.9218)
# (-8.4553, 119.8691)
# (64.1265, -21.8174)
# (-6.3144, 143.9555)
# 49

# %%
combined = coords + coords2
print(len(combined))
# Out:
# 102

# %%
import matplotlib.pyplot as plt
from geopy.geocoders import Nominatim

plt.figure(figsize=(10, 6))

# Create a Cartopy PlateCarree projection
ax = plt.axes(projection=ccrs.PlateCarree())

# Add coastlines
ax.coastlines()

# List of place names, latitudes, and longitudes
places = [
    ('Galápagos Islands, Ecuador', -0.7392, -90.3192),
    ('Costa Rica', 9.7489, -83.7534),
    ('Rwanda/Uganda', -1.9403, 29.8739),
    # Add the rest of the places here...
]

# Plot the coordinates on the map
for place in places:
    name, lat, lon = place
    ax.plot(lon, lat, 'ro', markersize=5)  # Adjust marker properties as needed
    plt.text(lon, lat, name, fontsize=8, ha='center', va='bottom')

# Show the map
plt.title("World Map with Coordinates")
plt.show()
